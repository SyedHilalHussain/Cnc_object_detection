# %% [markdown]
# # YOLO26 Video Object Detection — Colab GPU setup
# Runs the same detection app as locally, but on Colab's free GPU. Runtime > Change runtime type > GPU, before running these cells.

# %%
# !nvidia-smi

# %%
REPO_URL = "REPLACE_WITH_YOUR_GITHUB_REPO_URL"
# !git clone $REPO_URL repo
# %cd repo

# %%
# !pip install -q -r requirements.txt

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")

# %% [markdown]
# This launches the same Gradio app as locally. Since Colab has no direct access to `localhost`, it detects the Colab environment automatically and opens a public `gradio.live` share link (valid ~72 hours) instead — click the link that gets printed below.

# %%
# !python app.py
